# %%
import requests
from dotenv import load_dotenv
import os
from urllib.parse import quote

load_dotenv()

api_key = os.getenv("GEOAPIFY_API_KEY")

text = "1600 "  
encoded_text = quote(text)  

url = (
    "https://api.geoapify.com/v1/geocode/search?"
    f"text={encoded_text}"
    "&filter=circle:-77.03460987083406,38.89380923044945,120000"
    "&format=json"
    f"&apiKey={api_key}"
)

response = requests.get(url)

# Handle the response
if response.status_code == 200:
    data = response.json()

    if data['results'] == []:
        print("None")
    else:
        print(data['results'])
        for results in data['results']:
            print(results["formatted"])
            print(results["lon"])
            

    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# [{'country_code': 'us', 'name': '1600 Wilson Boulevard', 'housenumber': '1600', 'street': 'North Wilson Boulevard', 'country': 'United States', 'county': 'Arlington County', 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'postcode': '22209', 'state': 'Virginia', 'city': 'Arlington', 'suburb': 'Rosslyn', 'state_code': 'VA', 'lon': -77.077147, 'lat': 38.894032, 'result_type': 'amenity', 'formatted': '1600 Wilson Boulevard, 1600 North Wilson Boulevard, Arlington, VA 22209, United States of America', 'address_line1': '1600 Wilson Boulevard', 'address_line2': '1600 North Wilson Boulevard, Arlington, VA 22209, United States of America', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87C4VWVF+J4', 'plus_code_short': 'VWVF+J4, 22209 Arlington, United States', 'rank': {'popularity': 7.00248100928399, 'confidence': 1, 'match_type': 'full_match'}, 'place_id': '51027ff8f9ef4453c059ebc9fca36f724340f00102f9012045b30200000000c00201920315313630302057696c736f6e20426f756c6576617264e203206f70656e7374726565746d61703a76656e75653a7761792f3435333033303732', 'bbox': {'lon1': -77.0774731, 'lat1': 38.8938589, 'lon2': -77.0768203, 'lat2': 38.8942046}}, {'country_code': 'us', 'name': '1600 Duke St Garage', 'housenumber': '1600', 'street': 'Duke Street', 'country': 'United States', 'county': 'City of Alexandria', 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'state': 'Virginia', 'city': 'Alexandria', 'suburb': 'King Street Metro', 'state_code': 'VA', 'lon': -77.059012, 'lat': 38.803535, 'result_type': 'amenity', 'postcode': '22314', 'formatted': '1600 Duke St Garage, 1600 Duke Street, Alexandria, VA 22314, United States of America', 'address_line1': '1600 Duke St Garage', 'address_line2': '1600 Duke Street, Alexandria, VA 22314, United States of America', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87C4RW3R+C9', 'plus_code_short': '3R+C9, 22314 Alexandria, United States', 'rank': {'popularity': 5.6282021941868345, 'confidence': 1, 'match_type': 'full_match'}, 'place_id': '51948444dac64353c0597e18213cda664340f00102f9019384210d00000000c00201920313313630302044756b6520537420476172616765e203216f70656e7374726565746d61703a76656e75653a7761792f323230333030343335', 'bbox': {'lon1': -77.0595602, 'lat1': 38.8033112, 'lon2': -77.0582297, 'lat2': 38.8037219}}, {'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'name': "Mathew's 1600", 'country': 'United States', 'country_code': 'us', 'state': 'Maryland', 'county': 'Baltimore County', 'city': 'Catonsville', 'postcode': '21228', 'street': 'Frederick Road', 'housenumber': '1600', 'lon': -76.7480291669647, 'lat': 39.268685899999994, 'state_code': 'MD', 'result_type': 'amenity', 'formatted': "Mathew's 1600, 1600 Frederick Road, Catonsville, MD 21228, United States of America", 'address_line1': "Mathew's 1600", 'address_line2': '1600 Frederick Road, Catonsville, MD 21228, United States of America', 'category': 'catering.restaurant', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87F57792+FQ', 'plus_code_short': '7792+FQ Catonsville, Baltimore County, United States', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 4.531 ...
# 1600 Wilson Boulevard, 1600 North Wilson Boulevard, Arlington, VA 22209, United States of America
# -77.077147
# 1600 Duke St Garage, 1600 Duke Street, Alexandria, VA 22314, United States of America
# -77.059012
# Mathew's 1600, 1600 Frederick Road, Catonsville, MD 21228, United States of America
# -76.7480291669647
# 1600 Tysons Boulevard, Tysons, VA 22101, United States of America
# -77.22544404008468
# 1600 Wilson Boulevard, Arlington, VA 22209, United States of America
# -77.07714671184327
# Error: 200
# {"results":[{"country_code":"us","name":"1600 Wilson Boulevard","housenumber":"1600","street":"North Wilson Boulevard","country":"United States","county":"Arlington County","datasource":{"sourcename":"openstreetmap","attribution":"© OpenStreetMap contributors","license":"Open Database License","url":"https://www.openstreetmap.org/copyright"},"postcode":"22209","state":"Virginia","city":"Arlington","suburb":"Rosslyn","state_code":"VA","lon":-77.077147,"lat":38.894032,"result_type":"amenity","formatted":"1600 Wilson Boulevard, 1600 North Wilson Boulevard, Arlington, VA 22209, United States of America","address_line1":"1600 Wilson Boulevard","address_line2":"1600 North Wilson Boulevard, Arlington, VA 22209, United States of America","timezone":{"name":"America/New_York","offset_STD":"-05:00","offset_STD_seconds":-18000,"offset_DST":"-04:00","offset_DST_seconds":-14400,"abbreviation_STD":"EST","abbreviation_DST":"EDT"},"plus_code":"87C4VWVF+J4","plus_code_short":"VWVF+J4, 22209 Arlington, United States","rank":{"popularity":7.00248100928399,"confidence":1,"match_type":"full_match"},"place_id":"51027ff8f9ef4453c059ebc9fca36f724340f00102f9012045b30200000000c00201920315313630302057696c736f6e20426f756c6576617264e203206f70656e7374726565746d61703a76656e75653a7761792f3435333033303732","bbox":{"lon1":-77.0774731,"lat1":38.8938589,"lon2":-77.0768203,"lat2":38.8942046}},{"country_code":"us","name":"1600 Duke St Garage","housenumber":"1600","street":"Duke Street","country":"United States","county":"City of Alexandria","datasource":{"sourcename":"openstreetmap","attribution":"© OpenStreetMap contributors","license":"Open Database License","url":"https://www.openstreetmap.org/copyright"},"state":"Virginia","city":"Alexandria","suburb":"King Street Metro","state_code":"VA","lon":-77.059012,"lat":38.803535,"result_type":"amenity","postcode":"22314","formatted":"1600 Duke St Garage, 1600 Duke Street, Alexandria, VA 22314, United States of America","address_line1":"1600 Duke St Garage","address_line2":"1600 Duke Street, Alexandria, VA 22314, United States of America","timezone":{"name":"America/New_York","offset_STD":"-05:00","offset_STD_seconds":-18000,"offset_DST":"-04:00","offset_DST_seconds":-14400,"abbreviation_STD":"EST","abbreviation_DST":"EDT"},"plus_code":"87C4RW3R+C9","plus_code_short":"3R+C9, 22314 Alexandria, United States","rank":{"popularity":5.6282021941868345,"confidence":1,"match_type":"full_match"},"place_id":"51948444dac64353c0597e18213cda664340f00102f9019384210d00000000c00201920313313630302044756b6520537420476172616765e203216f70656e7374726565746d61703a76656e75653a7761792f323230333030343335","bbox":{"lon1":-77.0595602,"lat1":38.8033112,"lon2":-77.0582297,"lat2":38.8037219}},{"datasource":{"sourcename":"openstreetmap","attribution":"© OpenStreetMap contributors","license":"Open Database License","url":"https://www.openstreetmap.org/copyright"},"name":"Mathew's 1600","country":"United States","country_code":"us","state":"Maryland","county":"Baltimore County","city":"Catonsville","postcode":"21228","street":"Frederick Road","housenumber":"1600","lon":-76.7480291669647,"lat":39.268685899999994,"state_code":"MD","result_type":"amenity","formatted":"Mathew's 1600, 1600 Frederick Road, Catonsville, MD 21228, United States of America","address_line1":"Mathew's 1600","address_line2":"1600 Frederick Road, Catonsville, MD 21228, United States of America","category":"catering.restaurant","timezone":{"name":"America/New_York","offset_STD":"-05:00","offset_STD_seconds":-18000,"offset_DST":"-04:00","offset_DST_seconds":-14400,"abbreviation_STD":"EST","abbreviation_DST":"EDT"},"plus_code":"87F57792+FQ","plus_code_short":"7792+FQ Catonsville, Baltimore County, United States","rank":{"importance":0.00000999999999995449,"popularity":4.531574727636906,"confidence":1,"match_type":"full_match"},"place_id":"515224bab5df2f53c059bab2b04c64a24340f00102f9011474e60800000000c0020192030d4d617468657727732031363030e203216f70656e7374726565746d61703a76656e75653a ...

# %%
import pandas as pd 


crime_data = pd.read_csv("/Users/terrelldavis/Desktop/Personal Projects/SafeRadiusDC/dc-crimes-search-results.csv")

crime_data["START_DATE"] = pd.to_datetime(crime_data["START_DATE"], format="%m/%d/%Y, %I:%M:%S %p")
crime_data["MONTH"] = crime_data['START_DATE'].dt.month_name()
crime_data["DAY_NUMBER"] = crime_data['START_DATE'].dt.days_in_month
numerical_desc = crime_data.groupby("OFFENSE")[['DAY_NUMBER']].describe()

categorical_desc = crime_data.groupby("OFFENSE")[['METHOD', 'SHIFT', 'BLOCK','MONTH']].describe(include='all')

df_describe = pd.concat([numerical_desc, categorical_desc], axis=1)
#df_describe.columns = ['_'.join(col).strip() for col in df_describe.columns.values]

#df_describe.to_csv("/Users/terrelldavis/Desktop/Personal Projects/SafeRadiusDC/infotest.csv", index=False)
df_describe
# Out:
#                            DAY_NUMBER                                          \
#                                 count       mean       std   min    25%   50%
# OFFENSE
# arson                             4.0  30.000000  0.816497  29.0  29.75  30.0
# assault w/dangerous weapon      800.0  30.458750  0.652941  29.0  30.00  31.0
# burglary                        722.0  30.508310  0.636881  29.0  30.00  31.0
# homicide                        142.0  30.443662  0.668699  29.0  30.00  31.0
# motor vehicle theft            3697.0  30.481201  0.659378  29.0  30.00  31.0
# robbery                        1593.0  30.445700  0.678804  29.0  30.00  31.0
# sex abuse                       121.0  30.446281  0.694627  28.0  30.00  31.0
# theft f/auto                   4845.0  30.460475  0.669262  29.0  30.00  31.0
# theft/other                    9345.0  30.478866  0.670763  29.0  30.00  31.0
#
#                                         METHOD         ...     SHIFT        \
#                               75%   max  count unique  ...       top  freq
# OFFENSE                                                ...
# arson                       30.25  31.0      4      1  ...   evening     3
# assault w/dangerous weapon  31.00  31.0    801      3  ...  midnight   362
# burglary                    31.00  31.0    722      3  ...       day   313
# homicide                    31.00  31.0    142      3  ...  midnight   142
# motor vehicle theft         31.00  31.0   3699      3  ...       day  1518
# robbery                     31.00  31.0   1593      3  ...  midnight   708
# sex abuse                   31.00  31.0    121      3  ...   evening    53
# theft f/auto                31.00  31.0   4846      3  ...       day  2342
# theft/other                 31.00  31.0   9345      3  ...   evening  4291
#
#                            BLOCK         \
#                            count unique
# OFFENSE
# arson                          4      4
# assault w/dangerous weapon   801    626
# burglary                     722    550
# homicide                     142    131
# motor vehicle theft         3699   2393
# robbery                     1593   1260
# sex abuse                    121    115
# theft f/auto                4846   2923
# theft/other                 9345   2885
#
#                                                                             \
#                                                                   top freq
# OFFENSE
# arson                                900 - 999 block of 5th street se    1
# assault w/dangerous weapon   4000 - 4121 block of minnesota avenue ne   10
# burglary                             1500 - 1599 block of u street nw    7
# homicide                           4916 - 5066 block of jay street ne    3
# motor vehicle theft         500 - 799 block of rhode island avenue ne   32
# robbery                              1100 - 1199 block of u street nw    7
# sex abuse                            900 - 999 block of 9th street nw    2
# theft f/auto                500 - 799 block of rhode island avenue ne   31
# theft/other                       3100 - 3299 block of 14th street nw  277
#
#                            MONTH
#                            count unique      top  freq
# OFFENSE
# arson                          4      4    March     1
# assault w/dangerous weapon   800      9     June   116
# burglary                     722     11   August   118
# homicide                     142     11     July    19
# motor vehicle theft         3697     12      May   462
# robbery                     1593     10  January   216
# sex abuse                    121     11    April    19
# theft f/auto                4845     12      May   645
# theft/other                 9345     12     July  1240
#
# [9 rows x 24 columns]

# %%
b gvv
# Out:
#   Cell In[71], line 1
#     b gvv
#       ^
# SyntaxError: invalid syntax
